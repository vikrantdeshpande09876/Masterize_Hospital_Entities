# %% [markdown]
# ## 1. Initialization
#
# > a. Read the excel/csv containing the entire query-output
#
# > b. Initialize the parameters of thresholds, directories, and fields to concat for generating individual as well as combined match-score
#
# > c. Get the unique list of countries in present dataframe

# %%
import time, numpy as np, pandas as pd, re, string, subprocess #, recordlinkage

_STATIC_FILE_NAME="SM_Temp_Shortlist.xlsx"
_RAW_SCORES_DIRECTORY='Raw_Scores'
_CLEANED_SCORES_DIRECTORY='Cleaned_Scores'
_MASTER_DATA_DIRECTORY='Master_Data'
_FIELDS_TO_CONCAT={
    'CONCAT_ADDRESS':   ['ADDRESS_LINE_1','ADDRESS_LINE_2','ADDRESS_LINE_3']#, 'CONCAT_SRC':       ['SITE_NAME','STATE','CITY','CONCAT_ADDRESS','POSTAL_CODE']
                }

_COLUMNS_TO_CLEAN=['ADDRESS_LINE_1','ADDRESS_LINE_2','ADDRESS_LINE_3','SITE_NAME','STATE','CITY','POSTAL_CODE']
_BINARIES_NAME="levenshtein"
_BINARIES_EXTENSION=".dll"
_MAXSIZE=5000

_THRESHOLD_FOR_INDIVIDUAL=0.85
#_THRESHOLD_FOR_ENTIRE_COMBINED=0.55
_THRESHOLD_FOR_ADDRESS_COMBINED=0.75

_THRESHOLDS_DICT={
    'CONCAT_ADDRESS': _THRESHOLD_FOR_ADDRESS_COMBINED,
    #'CONCAT_SRC': _THRESHOLD_FOR_ENTIRE_COMBINED, 
    'SITE_NAME': _THRESHOLD_FOR_INDIVIDUAL,
    'STATE': _THRESHOLD_FOR_INDIVIDUAL,
    'CITY': _THRESHOLD_FOR_INDIVIDUAL,
    'POSTAL_CODE': _THRESHOLD_FOR_INDIVIDUAL
    }
_COLS_FOR_TOTAL_MATCH_CALC=[colname+'_COMPARISON_SCORE' for colname in _THRESHOLDS_DICT]

_SCALING_FACTOR=3

_TOTAL_MATCHES_THRESHOLD=3


def write_df_to_csv(df, root_dir='', curr_country='', file_suffix='_temp.csv', index_flag=False):
    try:
        abs_path=os.path.join(root_dir, curr_country+file_suffix)
        df.to_csv(abs_path, index=index_flag)
        print(f'\nSuccessfully created \{abs_path}!')
    except:
        print(f'\nSomething went wrong while writing the file. Please check if it is currently in use.')


def preprocess_dataframe(df):
    df.replace(np.nan, '', inplace=True)
    for colname in df.columns.values:
        if colname=='COUNTRY':
            df[colname]=df[colname].apply(lambda x: x.replace(' ','_'))
        df[colname]=df[colname].astype(str).apply(lambda x: x.strip())


def clean_dataframe(df, replace_punctuations=True):
    # Replaced another special character which was causing Italy CSV file read to fail in R
    if replace_punctuations:
        special_chars=re.escape(string.punctuation)+''
        print('\nSpecial Character that will be replaced are:  ', special_chars) # !"\\#\\$%\\&\'\\(\\)\\*\\+,\\-\\./:;<=>\\?@\\[\\\\\\]\\{\\|\\}\\~
    for colname in df.columns.values:
        if colname in _COLUMNS_TO_CLEAN and replace_punctuations:
            df[colname]=df[colname].replace(r'['+special_chars+']', '', regex=True).str.lower()
    for colname, cols_to_concat in _FIELDS_TO_CONCAT.items():
        df[colname]=df[cols_to_concat].apply(lambda single_row: ''.join(single_row.values), axis=1)
    df.drop(labels=_FIELDS_TO_CONCAT['CONCAT_ADDRESS'], axis=1, inplace=True)


def scale_up_comparison_score(df, colname='SITE_NAME_COMPARISON_SCORE', scaling_factor=_SCALING_FACTOR):
    print(f'\nScaling up {colname} by {scaling_factor}')
    df[colname]=df[colname].apply(lambda x: x*scaling_factor)


def replace_cyclic_dependencies(df, child_indicator, master_indicator):
    arr=set(df[child_indicator].array)
    for val in df[master_indicator]:
        if val in arr:
            replace_val=df[df[child_indicator]==val][master_indicator].values[0]
            print(val,' found in normalized_duplicates[',child_indicator,']. Replacement: ', replace_val)
            df[master_indicator].replace(val, replace_val, inplace=True)
    return df


def return_top_match(df, child_column, score_key_column):
    normalized_duplicates=df.sort_values(by=[child_column]).sort_values(by=[score_key_column],ascending=False)
    normalized_duplicates=normalized_duplicates.groupby(child_column).head(1).sort_values(by=[child_column])
    return normalized_duplicates


site_master_df=pd.read_excel(_STATIC_FILE_NAME, index_col=0)
preprocess_dataframe(site_master_df)

countries=list(site_master_df['COUNTRY'].unique())
huge_countries=list(site_master_df['COUNTRY'].value_counts()[site_master_df['COUNTRY'].value_counts() > _MAXSIZE].index)
for c in huge_countries:
    countries.remove(c)

print('\nUnique Countries having counts lesser than ', _MAXSIZE, ': ', countries)
# Out:
# Unique Countries having counts lesser than  5000 :  ['United_States']

# %% [markdown]
# ## 2. Process data in batches: getting scores of all the candidate-pairs is highly computation intensive. RAM crashes for incoming batch-size>4000
# > a. Partition the entire input dataset based on country-name. For-loop to do the entire process for all countries.
#
# > b. Create a concatenated (address) field and drop the individual 3 address fields
#
# > c. Create a concatenated (name, address) field

# %%
# todo: for loop- Research on multithreading to speed up country-wise batches. RAM might crash for incoming batch-size>4000.

c=0
curr_country=countries[c]
country_df=site_master_df[site_master_df['COUNTRY']==curr_country]
print(curr_country)
clean_dataframe(country_df)
write_df_to_csv(df=country_df[_THRESHOLDS_DICT.keys()], curr_country=curr_country, file_suffix='_country_df.csv', index_flag=True)

# todo: Imputation of address values where Site-name is exactly the same, otherwise it'll result in 2 separate master-records

print(f'\n{curr_country} has {country_df.shape[0]} records')
# Out:
# United_States
#
# Special Character that will be replaced are:   !"\#\$%\&'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~
#
# Successfully created \United_States_country_df.csv!
#
# United_States has 1000 records

# %% [markdown]
# ## 3. Initialize the candidate-pairs for comparison via the Index() object, and a Comparer() object with set of fields to compare amongst the candidate pairs
#
# ### Currently configured to run this match-score generation in R, such that:
#
# > if individual fields' match-score > 85% , then set the *_col_*_COMPARISON_SCORE column to 1, else 0
#
# > if combined address-fields' match-score > 75% , then set the CONCAT_ADDRESS_COMPARISON_SCORE column to 1, else 0
#
# ### Comparer algorithm can be: 'jaro', 'jarowinkler', 'levenshtein', 'damerau_levenshtein', 'qgram', 'cosine', 'smith_waterman', 'lcs'
#
# ### You can also set n_job=-1 to use up all cores available for parallel-computation of scores for the candidate-pairs.

# %%
# todo: invoke the R-code from Python using 32-bit Rscript 3.4.4 command
from subprocess import Popen, PIPE

pipe = Popen(
    [
    "C:/Program Files/R/R-3.4.4/bin/i386/Rscript", "Site_Master_Record_Linkage.R",
    f"{_BINARIES_NAME} {_BINARIES_EXTENSION} {_THRESHOLD_FOR_INDIVIDUAL} {_THRESHOLD_FOR_ADDRESS_COMBINED} {_SCALING_FACTOR} {curr_country} {_RAW_SCORES_DIRECTORY} {_TOTAL_MATCHES_THRESHOLD} Dedup NA NA"
    ],
    cwd="C:/Users/vdeshpande/Desktop/Del_Project-Takeda/Site_Master_Repo/",
    stdin=PIPE, stdout=PIPE, stderr=PIPE,shell=True
    )

output, error = pipe.communicate()

# Print R-console output
if pipe.returncode == 0:            
    print('R OUTPUT:\n',output.decode())
else:
    print('R OUTPUT:\n',output.decode())
    print('R ERROR:\n',error.decode())
# Out:
# R OUTPUT:
#  [1] "levenshtein .dll 0.85 0.75 3 United_States Raw_Scores 3 Dedup NA NA"
# [1] "Loading levenshtein.dll !"
#          used (Mb) gc trigger (Mb) max used (Mb)
# Ncells 120132  3.3     350000  9.4   302969  8.1
# Vcells 169833  1.3     786432  6.0   697526  5.4
# [1] "NRows= 1000 , Candidate-pairs= 499500 , Columns are "
# [1] "SR_NUM"         "CONCAT_ADDRESS" "SITE_NAME"      "STATE"
# [5] "CITY"           "POSTAL_CODE"
# [1] "N_combinations= 499500 , Columns are "
# [1] "id1"            "id2"            "CONCAT_ADDRESS" "SITE_NAME"
# [5] "STATE"          "CITY"           "POSTAL_CODE"    "is_match"
# [1] "Scaling up column scores if threshold crossed"
# [1] "SITE_NAME  :  0.85"
# [1] "STATE  :  0.85"
# [1] "CITY  :  0.85"
# [1] "POSTAL_CODE  :  0.85"
# [1] "CONCAT_ADDRESS  :  0.75"
# Time difference of 10.77138 secs
# [1] "Raw_Scores//United_States_Score_Features.csv"
# [1] "Successfully created //Raw_Scores//United_States_Score_Features.csv !"

# %% [markdown]
# ## 4. Get the set of potential duplicates where TOTAL_SCORE > THRESHOLD
#
# ### Currently configured to perform this in R itself.
#
# > R code will finally generate the *Country*_Score_Features.csv in the /Raw_Scores/ directory

# %%
duplicates=pd.read_csv(os.path.join(_RAW_SCORES_DIRECTORY, curr_country+'_Score_Features.csv'))
duplicates['COUNTRY']=curr_country
duplicates.head(30)
# Out:
#     SR_NUM_1  SR_NUM_2  SITE_NAME_COMPARISON_SCORE  STATE_COMPARISON_SCORE  \
# 0      15060     15059                           1                       1
# 1      15160     15059                           0                       1
# 2      15165     15059                           1                       1
# 3      15166     15059                           1                       1
# 4      15167     15059                           1                       1
# 5      15168     15059                           1                       1
# 6      15169     15059                           1                       1
# 7      15170     15059                           1                       1
# 8      15171     15059                           1                       1
# 9      15172     15059                           1                       1
# 10     15173     15059                           1                       1
# 11     15561     15059                           0                       0
# 12     15562     15059                           0                       0
# 13     15563     15059                           0                       0
# 14     15564     15059                           0                       0
# 15     15569     15059                           0                       0
# 16     15585     15059                           0                       0
# 17     15160     15060                           0                       1
# 18     15165     15060                           1                       1
# 19     15166     15060                           1                       1
# 20     15167     15060                           1                       1
# 21     15168     15060                           1                       1
# 22     15169     15060                           1                       1
# 23     15170     15060                           1                       1
# 24     15171     15060                           1                       1
# 25     15172     15060                           1                       1
# 26     15173     15060                           1                       1
# 27     15561     15060                           0                       0
# 28     15562     15060                           0                       0
# 29     15563     15060                           0                       0
#
#     CITY_COMPARISON_SCORE  POSTAL_CODE_COMPARISON_SCORE  \
# 0                       1                             1
# 1                       1                             0
# 2                       1                             0
# 3                       1                             0
# 4                       1                             0
# 5                       1                             0
# 6                       1                             0
# 7                       1                             0
# 8                       1                             0
# 9                       1                             0
# 10                      1                             0
# 11                      0                             0
# 12                      0                             0
# 13                      0                             0
# 14                      0                             0
# 15                      0                             0
# 16                      0                             0
# 17                      1                             0
# 18                      1                             0
# 19                      1                             0
# 20                      1                             0
# 21                      1                             0
# 22                      1                             0
# 23                      1                             0
# 24                      1                             0
# 25                      1                             0
# 26                      1                             0
# 27                      0                             0
# 28                      0                             0
# 29                      0                             0
#
#     CONCAT_ADDRESS_COMPARISON_SCORE  NUM_OF_MATCHES_FOUND        COUNTRY
# 0                                 3                     7  United_States
# 1                                 3                     5  United_States
# 2                                 0                     3  United_States
# 3                                 3                     6  United_States
# 4                                 0                     3  United_States
# 5                                 3                     6  United_States
# 6                                 0                     3  United_States
# 7                                 3                     6  United_States
# 8                                 3                     6  United_States
# 9                                 3                     6  United_States
# 10                                3                     6  United_States
# 11                                3                     3  United_States
# 12                                3                     3  United_States
# 13                                3                     3  United_States
# 14                                3                     3  United_States
# 15                                3                     3  United_States
# 16                                3                     3  United_States
# 17                                3                     5  United_States
# 18                                0                     3  United_States
# 19                                3                     6  United_States
# 20                                0                     3  United_States
# 21                                3                     6  United_States
# 22                                0                     3  United_States
# 23                                3                     6  United_States
# 24                                3                     6  United_States
# 25                                3                     6  United_States
# 26                                3                     6  United_States
# 27                                3                     3  United_States
# 28                                3                     3  United_States
# 29                                3                     3  United_States

# %% [markdown]
# ## 5. Choose the best match for incoming child records based on highest total-score

# %%
normalized_duplicates=return_top_match(df=duplicates, child_column='SR_NUM_1', score_key_column='NUM_OF_MATCHES_FOUND')
normalized_duplicates.head(30)
# Out:
#      SR_NUM_1  SR_NUM_2  SITE_NAME_COMPARISON_SCORE  STATE_COMPARISON_SCORE  \
# 0       15060     15059                           1                       1
# 33      15062     15061                           1                       0
# 34      15070     15066                           0                       0
# 41      15071     15070                           1                       1
# 42      15072     15070                           1                       1
# 74      15073     15072                           1                       1
# 60      15074     15071                           1                       1
# 76      15075     15072                           1                       1
# 104     15076     15074                           1                       1
# 63      15077     15071                           0                       1
# 150     15079     15078                           1                       1
# 158     15080     15079                           1                       1
# 165     15081     15080                           1                       1
# 166     15082     15080                           1                       1
# 161     15083     15079                           1                       1
# 177     15084     15082                           1                       1
# 169     15085     15080                           1                       1
# 157     15086     15078                           0                       1
# 186     15088     15087                           1                       1
# 192     15089     15088                           1                       1
# 188     15090     15087                           1                       1
# 194     15091     15088                           1                       1
# 199     15092     15089                           1                       1
# 203     15093     15090                           1                       1
# 207     15095     15094                           0                       0
# 210     15098     15097                           0                       1
# 230     15099     15098                           0                       1
# 231     15100     15098                           0                       1
# 258     15101     15100                           0                       0
# 259     15102     15100                           0                       1
#
#      CITY_COMPARISON_SCORE  POSTAL_CODE_COMPARISON_SCORE  \
# 0                        1                             1
# 33                       1                             1
# 34                       0                             0
# 41                       1                             1
# 42                       1                             1
# 74                       1                             1
# 60                       1                             1
# 76                       1                             1
# 104                      1                             1
# 63                       0                             0
# 150                      1                             1
# 158                      1                             1
# 165                      1                             1
# 166                      1                             1
# 161                      1                             1
# 177                      1                             1
# 169                      1                             1
# 157                      1                             1
# 186                      1                             1
# 192                      1                             1
# 188                      1                             1
# 194                      1                             1
# 199                      1                             1
# 203                      1                             1
# 207                      1                             1
# 210                      1                             1
# 230                      1                             1
# 231                      1                             1
# 258                      1                             1
# 259                      1                             1
#
#      CONCAT_ADDRESS_COMPARISON_SCORE  NUM_OF_MATCHES_FOUND        COUNTRY
# 0                                  3                     7  United_States
# 33                                 0                     3  United_States
# 34                                 3                     3  United_States
# 41                                 3                     7  United_States
# 42                                 3                     7  United_States
# 74                                 3                     7  United_States
# 60                                 3                     7  United_States
# 76                                 3                     7  United_States
# 104                                3                     7  United_States
# 63                                 3                     4  United_States
# 150                                0                     4  United_States
# 158                                3                     7  United_States
# 165                                3                     7  United_States
# 166                                3                     7  United_States
# 161                                3                     7  United_States
# 177                                3                     7  United_States
# 169                                3                     7  United_States
# 157                                3                     6  United_States
# 186                                3                     7  United_States
# 192                                3                     7  United_States
# 188                                3                     7  United_States
# 194                                3                     7  United_States
# 199                                3                     7  United_States
# 203                                3                     7  United_States
# 207                                3                     5  United_States
# 210                                0                     3  United_States
# 230                                0                     3  United_States
# 231                                0                     3  United_States
# 258                                3                     5  United_States
# 259                                0                     3  United_States

# %% [markdown]
# ## 5. Reusable function to replace the cyclic matches
# ### For example:
#
# >   Record45 matches with Record44
#
# >   Record67 matches with Record45
#
# ### In this case we should maintain:
# >   Record67 matches with Record44

# %%
normalized_duplicates=replace_cyclic_dependencies(df=normalized_duplicates, child_indicator='SR_NUM_1', master_indicator='SR_NUM_2')
normalized_duplicates
# Out:
# ized_duplicates[ SR_NUM_1 ]. Replacement:  15319
# 15321  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15319
# 15326  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15327  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15329  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15333  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15335  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15334  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15337  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15338  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15339  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15343  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15345  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15336  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15352  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15340  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15354  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15290  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15357  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15358  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15362  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15363  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15365  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15360  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15367  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15368  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15369  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15370  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15359  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15364  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15378  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15382  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15381
# 15383  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15381
# 15384  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15381
# 15388  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15162
# 15397  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15396
# 15399  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15396
# 15406  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15403
# 15409  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15403
# 15408  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15403
# 15414  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15413
# 15415  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15413
# 15416  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15413
# 15423  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15424  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15425  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15426  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15427  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15434  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15435  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15437  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15438  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15439  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15433  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15441  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15442  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15445  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15420
# 15449  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15448
# 15451  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15448
# 15457  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15459  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15460  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15462  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15461  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15468  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15470  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15456
# 15475  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15474
# 15476  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15474
# 15480  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15474
# 15481  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15474
# 15484  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15483
# 15486  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15483
# 15487  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15483
# 15485  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15483
# 15494  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15491
# 15493  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15491
# 15496  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15491
# 15497  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15491
# 15498  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15491
# 15503  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15502
# 15507  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15506
# 15514  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15516  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15518  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15519  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15522  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15524  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15526  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15528  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15529  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15531  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15532  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15533  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15537  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15536
# 15538  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15536
# 15542  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15541
# 15543  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15541
# 15549  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15552  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15553  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15554  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15555  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15557  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15559  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15560  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15561  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15562  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15565  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15156
# 15566  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15156
# 15567  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15156
# 15564  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15563  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15570  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15571  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15572  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15574  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15577  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15548
# 15580  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15579
# 15582  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15579
# 15584  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15156
# 15592  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15591
# 15593  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15591
# 15594  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15591
# 15604  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15602
# 15603  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15602
# 15615  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15613
# 15618  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15620  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15613
# 15619  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15622  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15624  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15613
# 15629  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15628
# 15631  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15628
# 15636  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15637  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15639  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15640  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15645  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15611
# 15646  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15613
# 15654  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15652
# 15661  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15663  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15665  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15664  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15668  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15662  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15659
# 15674  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15094
# 15678  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15677
# 15679  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15677
# 15682  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15677
# 15683  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15677
# 15684  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15677
# 15688  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15687
# 15689  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15687
# 15691  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15687
# 15693  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15687
# 15696  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15687
# 15702  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15698
# 15700  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15698
# 15710  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15709
# 15720  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15719
# 15723  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15722
# 15734  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15732
# 15733  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15732
# 15740  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15739
# 15741  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15739
# 15075  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15743  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15744  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15066
# 15747  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15749  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15751  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15750  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15754  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15752  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15761  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15758  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15753  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15764  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15766  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15765  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15769  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15772  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15746
# 15778  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15777
# 15782  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15781
# 15784  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15781
# 15799  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15798
# 15803  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15802
# 15804  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15802
# 15806  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15802
# 15810  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15809
# 15811  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15809
# 15812  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15809
# 15813  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15809
# 15820  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15513
# 15824  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15823
# 15825  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15823
# 15828  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15823
# 15830  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15823
# 15839  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15841  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15842  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15846  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15840  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15850  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15851  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15848  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15855  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15837
# 15860  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15859
# 15870  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15869
# 15871  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15869
# 15874  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15869
# 15881  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15880
# 15883  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15880
# 15884  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15880
# 15882  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15880
# 15889  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15866
# 15893  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15891
# 15894  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15891
# 15897  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15891
# 15901  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15900
# 15903  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15900
# 15905  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15900
# 15911  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15910
# 15918  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15917
# 15920  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15917
# 15919  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15917
# 15928  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15925
# 15929  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15925
# 15926  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15925
# 15933  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15932
# 15935  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15932
# 15936  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15932
# 15953  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15950
# 15952  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15950
# 15963  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15961
# 15968  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15970  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15971  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15972  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15974  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15977  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15980  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15979  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15985  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15986  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15987  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15967
# 15995  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 15994  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 15997  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16000  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 15999  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 15998  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16004  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16005  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16008  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16007  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  15993
# 16014  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16015  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16016  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16017  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16022  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16023  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16024  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16025  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16029  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16030  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16032  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16036  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16037  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16038  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16039  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16041  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16043  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16020  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16045  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16046  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16048  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16049  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16051  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16013
# 16056  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16054
# 16057  found in normalized_duplicates[ SR_NUM_1 ]. Replacement:  16054
#        SR_NUM_1  SR_NUM_2  SITE_NAME_COMPARISON_SCORE  STATE_COMPARISON_SCORE  \
# 0         15060     15059                           1                       1
# 33        15062     15061                           1                       0
# 34        15070     15066                           0                       0
# 41        15071     15066                           1                       1
# 42        15072     15066                           1                       1
# ...         ...       ...                         ...                     ...
# 13528     16053     16013                           1                       1
# 13551     16055     16054                           1                       1
# 13552     16056     16054                           1                       1
# 13555     16057     16054                           0                       0
# 13556     16058     16054                           1                       1
#
#        CITY_COMPARISON_SCORE  POSTAL_CODE_COMPARISON_SCORE  \
# 0                          1                             1
# 33                         1                             1
# 34                         0                             0
# 41                         1                             1
# 42                         1                             1
# ...                      ...                           ...
# 13528                      1                             1
# 13551                      1                             1
# 13552                      1                             1
# 13555                      1                             1
# 13556                      1                             1
#
#        CONCAT_ADDRESS_COMPARISON_SCORE  NUM_OF_MATCHES_FOUND        COUNTRY
# 0                                    3                     7  United_States
# 33                                   0                     3  United_States
# 34                                   3                     3  United_States
# 41                                   3                     7  United_States
# 42                                   3                     7  United_States
# ...                                ...                   ...            ...
# 13528                                3                     7  United_States
# 13551                                0                     4  United_States
# 13552                                3                     7  United_States
# 13555                                3                     5  United_States
# 13556                                0                     4  United_States
#
# [843 rows x 9 columns]

# %% [markdown]
# ## 6. CSV for static-analysis of matches

# %%
write_df_to_csv(df=normalized_duplicates, root_dir=_CLEANED_SCORES_DIRECTORY, curr_country=curr_country, file_suffix='_Cleaned_Feature_Scores.csv')
print('\n"SR_NUM_2" will be the master record')
# Out:
# Successfully created \Cleaned_Scores\United_States_Cleaned_Feature_Scores.csv!
#
# "SR_NUM_2" will be the master record

# %% [markdown]
# ## 7. Get the unique set of Master-Records and create a master CSV file for each country
#
# > a. Think of 'SR_NUM_1' as the list of incoming Primary-keys, and 'SR_NUM_2' as the value to which it should be mapped based on match-score
#
# > b. Hence, union of 'SR_NUM_1' & 'SR_NUM_2' will be entire set of duplicates
#
# > c. Stand-alone records in the current country_batch_dataframe will not fall in this entire set of duplicates
#
# > d. Master-records set wil be the sets of 'SR_NUM_2' & #c above.

# %%
a1=set(normalized_duplicates['SR_NUM_1'].values.tolist())
a2=set(normalized_duplicates['SR_NUM_2'].values.tolist())
country_set=set(country_df.index.values.tolist())
entire_duplicates_set=a1.union(a2)
no_match_set=country_set.difference(entire_duplicates_set)
master_record_ids=no_match_set.union(a2)



country_df_copy=site_master_df[site_master_df['COUNTRY']==curr_country]
preprocess_dataframe(df=country_df_copy)
clean_dataframe(df=country_df_copy, replace_punctuations=False)

print(f'{site_master_df.shape[0]} records get merged into {len(master_record_ids)}')
#country_master_df=country_df_copy.loc[master_record_ids].drop('CONCAT_SRC',axis=1)
country_master_df=country_df_copy.loc[master_record_ids]
write_df_to_csv(df=country_master_df, root_dir=_MASTER_DATA_DIRECTORY, curr_country=curr_country, index_flag=True, file_suffix='_Master.csv')
# Out:
# 1000 records get merged into 157
#
# Successfully created \Master_Data\United_States_Master.csv!

# %% [markdown]
# ## 8. Get the normalized-duplicates into a CSV to show translation of incoming record into single golden record
#
# > a. Create a master_cross_reference_df for the master_record_ids with relevant scores scaled up by _SCALING_FACTOR, and other comparison scores set to 1
#
# > b. concat it with the normalized_duplicates dataframe

# %%
master_record_score_array=[1.0]*len(master_record_ids)
master_record_df_dict={
    'SR_NUM_1': list(master_record_ids),
    'SR_NUM_2': list(master_record_ids),
    'SITE_NAME_COMPARISON_SCORE': master_record_score_array,
    'STATE_COMPARISON_SCORE': master_record_score_array,
    'CITY_COMPARISON_SCORE': master_record_score_array,
    'CONCAT_ADDRESS_COMPARISON_SCORE': master_record_score_array,
    'POSTAL_CODE_COMPARISON_SCORE': master_record_score_array }

cross_ref_df=pd.DataFrame(master_record_df_dict)
cross_ref_df['COUNTRY']=curr_country
scale_up_comparison_score(cross_ref_df,'CONCAT_ADDRESS_COMPARISON_SCORE',_SCALING_FACTOR)
cross_ref_df['NUM_OF_MATCHES_FOUND']=cross_ref_df[_COLS_FOR_TOTAL_MATCH_CALC].sum(axis=1)


cross_ref_df=cross_ref_df.append(normalized_duplicates)
cross_ref_df.sort_values(by=['SR_NUM_1'], axis=0, inplace=True)

write_df_to_csv(df=cross_ref_df, root_dir=_MASTER_DATA_DIRECTORY, curr_country=curr_country, file_suffix='_Raw_Cross_Ref.csv')
# Out:
# Scaling up CONCAT_ADDRESS_COMPARISON_SCORE by 3
#
# Successfully created \Master_Data\United_States_Raw_Cross_Ref.csv!

# %% [markdown]
# ## 9. Generate the report to display name & address fields of match-and-merge combinations
#
# > a. Merge the master_cross_reference_df with the country_batch_dataframe as a left-outer-join on Primary-key='SR_NUM_1'
#
# > b. Merge this master_cross_reference_df with the country_batch_dataframe as a left-outer-join on Primary-key='SR_NUM_2'

# %%
country_df_copy.reset_index(inplace=True)
country_df_colnames=country_df_copy.columns.values

country_df_copy.columns=[colname+'_1' for colname in country_df_colnames]
cross_ref_df=cross_ref_df.merge(country_df_copy, how='left', on='SR_NUM_1')

country_df_copy.columns=[colname+'_2' for colname in country_df_colnames]
cross_ref_df=cross_ref_df.merge(country_df_copy, how='left', on='SR_NUM_2')
cross_ref_df=cross_ref_df[['SR_NUM_1', 'SR_NUM_2', 'SITE_NAME_1','SITE_NAME_2','SITE_NAME_COMPARISON_SCORE','STATE_1','STATE_2','STATE_COMPARISON_SCORE', 'CITY_1','CITY_2','CITY_COMPARISON_SCORE','CONCAT_ADDRESS_1','CONCAT_ADDRESS_2','CONCAT_ADDRESS_COMPARISON_SCORE', 'POSTAL_CODE_1','POSTAL_CODE_2','POSTAL_CODE_COMPARISON_SCORE','NUM_OF_MATCHES_FOUND']]

write_df_to_csv(df=cross_ref_df, root_dir=_MASTER_DATA_DIRECTORY, curr_country=curr_country, file_suffix='_Cross_Ref_Full_Report.csv')
# Out:
# Successfully created \Master_Data\United_States_Cross_Ref_Full_Report.csv!
